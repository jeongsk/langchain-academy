# %%
 pip install -Uq langgraph langsmith langchain_groq langchain_openai langchain_tavily
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.6 MB/s eta 0:00:00

# %%
from os import environ
from google.colab import userdata

environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
environ["OPENROUTER_API_KEY"] = userdata.get('OPENROUTER_API_KEY')
environ["TAVILY_API_KEY"] = userdata.get('TAVILY_API_KEY')
environ["LANGSMITH_API_KEY"] = userdata.get('LANGSMITH_API_KEY')

environ["LANGCHAIN_TRACING_V2"] = "true"
environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
environ["LANGCHAIN_PROJECT"] = "15-LangGraph-Streaming-Steps"

# %%
from os import getenv
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
  api_key=getenv("OPENROUTER_API_KEY"),
  base_url="https://openrouter.ai/api/v1",
  model="x-ai/grok-4-fast:free",
  temperature=0
)

# %%
llm.invoke("안녕하세요.")
# Out:
# AIMessage(content='안녕하세요! xAI에서 만든 Grok입니다. 무슨 일로 도와드릴까요? 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 168, 'prompt_tokens': 122, 'total_tokens': 290, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 143, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 121}}, 'model_name': 'x-ai/grok-4-fast:free', 'system_fingerprint': 'fp_9362061f30', 'id': 'gen-1758872917-cHfTgkZ4Ljbt92HumVgZ', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--437eacd4-07c5-4697-802d-705245178c7c-0', usage_metadata={'input_tokens': 122, 'output_tokens': 168, 'total_tokens': 290, 'input_token_details': {'audio': 0, 'cache_read': 121}, 'output_token_details': {'reasoning': 143}})

# %%
from typing import TypedDict, Annotated
from langgraph.graph.message import add_messages

class State(TypedDict):
  messages: Annotated[list, add_messages]

# %%
def chatbot(state: State) -> State:
  response = llm.invoke(state.get("messages"))
  return State(messages=[response])

# %%
from langchain_core.messages import HumanMessage

chatbot(State(messages=[HumanMessage(content="안녕하세요.")]))
# Out:
# {'messages': [AIMessage(content='안녕하세요! 😊 xAI에서 만든 Grok입니다. 무슨 일로 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 203, 'prompt_tokens': 122, 'total_tokens': 325, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 178, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 121}}, 'model_name': 'x-ai/grok-4-fast:free', 'system_fingerprint': 'fp_9362061f30', 'id': 'gen-1758873121-n2eyJpPaBj2NVDOIizjP', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--643be2d9-b8c0-48b6-bf65-6074467a60b5-0', usage_metadata={'input_tokens': 122, 'output_tokens': 203, 'total_tokens': 325, 'input_token_details': {'audio': 0, 'cache_read': 121}, 'output_token_details': {'reasoning': 178}})]}

# %%
from langchain_tavily import TavilySearch

search = TavilySearch(max_results=3)
tools = [search]

llm_with_tools = llm.bind_tools(tools)

# %%
def chatbot_with_tools(state: State) -> State:
  response = llm_with_tools.invoke(state.get("messages"))
  return State(messages=[response])

# %%
from langgraph.prebuilt import ToolNode, tools_condition

tool_node = ToolNode(tools)

# %%
from langgraph.graph import StateGraph
from langgraph.checkpoint.memory import InMemorySaver

memory = InMemorySaver()

builder = StateGraph(State)
builder.add_node("chatbot", chatbot_with_tools)
builder.add_node("tools", tool_node)
builder.add_edge("tools", "chatbot")
builder.add_conditional_edges("chatbot", tools_condition)
builder.set_entry_point("chatbot")
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import display, Image

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
from random import random
from langchain_core.runnables.config import RunnableConfig

config = RunnableConfig(recursion_limit=10, configurable={"thread_id": str(random())})


input = State(messages=[HumanMessage(content="AI 관련 최신 뉴스를 검새해주세요")])

for event in graph.stream(input, config, stream_mode="updates"):
  print(event)
# Out:
# {'chatbot': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_01815526', 'function': {'arguments': '{"query":"latest AI news","topic":"news","include_favicon":false,"start_date":"2024-10-01","end_date":"2024-10-08"}', 'name': 'tavily_search'}, 'type': 'function', 'index': 0}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 606, 'prompt_tokens': 1803, 'total_tokens': 2409, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 522, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1802}}, 'model_name': 'x-ai/grok-4-fast:free', 'system_fingerprint': 'fp_9362061f30', 'id': 'gen-1758874499-kTRHe8ifjCH20z1nDOBP', 'service_tier': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--e2abc6d2-2eb9-4c0a-9454-4e1d41c8616f-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'latest AI news', 'topic': 'news', 'include_favicon': False, 'start_date': '2024-10-01', 'end_date': '2024-10-08'}, 'id': 'call_01815526', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1803, 'output_tokens': 606, 'total_tokens': 2409, 'input_token_details': {'audio': 0, 'cache_read': 1802}, 'output_token_details': {'reasoning': 522}})]}}
# {'tools': {'messages': [ToolMessage(content='{"query": "latest AI news", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://techcrunch.com/2024/10/02/cancer-ai-alliance-joins-medical-and-tech-expertise-together-with-40m-to-collaborate-on-next-gen-care/", "title": "Cancer AI Alliance joins medical and tech expertise together with $40M to collaborate on next-gen care - TechCrunch", "score": 0.61779, "published_date": "Wed, 02 Oct 2024 19:30:00 GMT", "content": "Latest\\t AI\\t Biotech & Health\\t Meta\\t With $40 million of cash and resources from big tech backers, the Cancer AI Alliance (CAIA) could be a huge step forward in precision medicine. The new organization aims to solve this by means of federated learning, a type of secure data collaboration where the raw data stays private, but can be used for the purposes of training AI and other computational systems. Ray-Ban Meta + facial recognition = Terminator vision for doxxing Ray-Ban Meta + facial recognition = Terminator vision for doxxing Devin Coldewey is a Seattle-based writer and photographer. Devin Coldewey is a Seattle-based writer and photographer. Ray-Ban Meta + facial recognition = Terminator vision for doxxing Latest in Biotech & Health", "raw_content": null}, {"url": "https://www.thesunchronicle.com/business/googles-search-engines-latest-ai-injection-will-answer-voiced-questions-about-video-and-photos/article_004b208e-d865-5bfc-ae8a-b8d3feb053c4.html", "title": "Google\'s search engine\'s latest AI injection will answer voiced questions about video and photos - The Sun Chronicle", "score": 0.6100127, "published_date": "Thu, 03 Oct 2024 22:21:38 GMT", "content": "Google\'s search engine\'s latest AI injection will answer voiced questions about video and photos | Business | thesunchronicle.com Google\'s search engine\'s latest AI injection will answer voiced questions about video and photos Google\'s search engine\'s latest AI injection will answer voiced questions about video and photos Google is addressing some of those ongoing worries by inserting even more links to other websites within the AI Overviews, which already have been reducing the visits to general news publishers such as The New York Times and technology review specialists such as TomsGuide.com, according to an analysis released last month by search traffic specialist BrightEdge.", "raw_content": null}, {"url": "https://aibusiness.com/generative-ai/generative-ai-video-for-self-driving-development-upgraded?__cf_chl_rt_tk=UH66E9_UsOGFR4iQWpIYvi802JakEKHaXAinDqpOH38-1727999366-0.0.1.1-5140", "title": "Generative AI Video for Self-Driving Development Upgraded - AI Business", "score": 0.568632, "published_date": "Thu, 03 Oct 2024 21:42:27 GMT", "content": "Generative AI Video for Self-Driving Development Upgraded AI Business is part of the Informa Tech Division of Informa PLC Recent in\xa0ML NASA, IBM Create AI Model to Predict WeatherNASA, IBM Create AI Model to Predict Weather How AI and IoT Are Reshaping AgricultureHow AI and IoT Are Reshaping Agriculture Recent in\xa0NLP More Than Words: How to Build Human Expertise into Generative AI ModelsMore Than Words: How to Build Human Expertise into Generative AI Models Data Data analytics Recent in\xa0Data Take It Steady: Getting the Most out of Generative AITake It Steady: Getting the Most out of Generative AI Recent in\xa0Automation Recent in\xa0Verticals Responsible AI AI Policy Explainable AI AI Ethics Recent in\xa0Responsible AI thumbnailResponsible AI", "raw_content": null}], "response_time": 0.52, "request_id": "327635df-0707-44b9-8d1c-48ec73bfbc56"}', name='tavily_search', id='9a34d201-c406-4582-891e-5361bbf4b22f', tool_call_id='call_01815526')]}}
# {'chatbot': {'messages': [AIMessage(content='### AI 관련 최신 뉴스 요약 (2024년 10월 초 기준)\n\n안녕하세요! "AI 관련 최신 뉴스"를 검색해 보았습니다. 최근 24시간 내 주요 뉴스를 중심으로 영어 기반 검색 결과를 바탕으로 요약하겠습니다. (검색 도구가 영어로 최적화되어 있어 영어 쿼리를 사용했으나, 한국어로 번역/요약했습니다.) 더 자세한 내용은 링크를 확인하세요. 뉴스는 빠르게 변할 수 있으니 최신 업데이트를 권장합니다.\n\n#### 1. **Cancer AI Alliance (CAIA) 출범: 암 치료 AI 협력 프로젝트에 4,000만 달러 투자**\n   - **요약**: 메타(Meta) 등 빅테크 기업의 지원으로 4,000만 달러 규모의 Cancer AI Alliance가 설립되었습니다. 의료 및 기술 전문가들이 연합해 연합 학습(federated learning) 기술을 활용, 환자 데이터 프라이버시를 유지하면서 AI를 통해 정밀 의학을 발전시킬 계획입니다. 이는 암 치료의 차세대 접근으로 큰 주목을 받고 있습니다.\n   - **발행일**: 2024년 10월 2일\n   - **출처**: TechCrunch\n   - **링크**: [기사 보기](https://techcrunch.com/2024/10/02/cancer-ai-alliance-joins-medical-and-tech-expertise-together-with-40m-to-collaborate-on-next-gen-care/)\n\n#### 2. **구글 검색 엔진에 AI 업그레이드: 비디오/사진에 대한 음성 질문 지원**\n   - **요약**: 구글이 검색 엔진에 새로운 AI 기능을 추가했습니다. 이제 비디오나 사진에 대해 음성으로 질문을 하면 AI가 답변을 제공합니다. 이는 AI 개요(AI Overviews) 기능을 강화한 것으로, 뉴욕타임스 등 미디어 트래픽 감소 문제를 완화하기 위해 외부 링크를 더 많이 포함합니다. 검색 경험을 더 직관적으로 만들려는 시도입니다.\n   - **발행일**: 2024년 10월 3일\n   - **출처**: The Sun Chronicle\n   - **링크**: [기사 보기](https://www.thesunchronicle.com/business/googles-search-engines-latest-ai-injection-will-answer-voiced-questions-about-video-and-photos/article_004b208e-d865-5bfc-ae8a-b8d3feb053c4.html)\n\n#### 3. **자율주행 개발을 위한 생성 AI 비디오 기술 업그레이드**\n   - **요약**: 자율주행 자동차 개발을 위한 생성 AI 비디오 기술이 업그레이드되었습니다. 이는 AI 비즈니스 분야에서 최근 트렌드로, NASA/IBM의 날씨 예측 AI 모델이나 AI/IoT 농업 적용 등과 연계된 맥락에서 논의되고 있습니다. 더 현실적인 시뮬레이션 비디오 생성으로 자율주행 테스트를 가속화할 전망입니다.\n   - **발행일**: 2024년 10월 3일\n   - **출처**: AI Business\n   - **링크**: [기사 보기](https://aibusiness.com/generative-ai/generative-ai-video-for-self-driving-development-upgraded)\n\n이 뉴스들은 AI의 의료, 검색, 자율주행 분야에서의 실용적 적용을 강조합니다. 더 구체적인 주제(예: 특정 AI 회사나 한국 관련 뉴스)나 추가 검색이 필요하시면 말씀해주세요! 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1101, 'prompt_tokens': 3279, 'total_tokens': 4380, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 320, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2403}}, 'model_name': 'x-ai/grok-4-fast:free', 'system_fingerprint': 'fp_9362061f30', 'id': 'gen-1758874504-tYWYEOC0Q9xXrVDOZzZS', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--1dc2e79b-aec2-45ed-b611-de9f0d6d4060-0', usage_metadata={'input_tokens': 3279, 'output_tokens': 1101, 'total_tokens': 4380, 'input_token_details': {'audio': 0, 'cache_read': 2403}, 'output_token_details': {'reasoning': 320}})]}}

# %%
from random import random
from langchain_core.runnables.config import RunnableConfig

config = RunnableConfig(recursion_limit=10, configurable={"thread_id": str(random())})


input = State(messages=[HumanMessage(content="AI 관련 최신 뉴스를 검새해주세요")])

for event in graph.stream(input, config, stream_mode="messages"):
  print(event)
# Out:
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--59877a6f-c254-4275-a4d1-f19489817ca0'), {'thread_id': '0.3348238247809542', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'checkpoint_ns': 'chatbot:a91c9579-49dc-ac92-c0b7-ac69018d71a8', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# ...
# (AIMessageChunk(content='하시', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='면', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' 말씀', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='해', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' 주', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='세요', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='검', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='색', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' 도', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='구', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' Tav', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='ily', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' Search', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' 최', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='신', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='성', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' 중심', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='으로', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=' 필', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='터', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='링', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'x-ai/grok-4-fast:free', 'system_fingerprint': 'fp_9362061f30'}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2'), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2', usage_metadata={'input_tokens': 3095, 'output_tokens': 974, 'total_tokens': 4069, 'input_token_details': {'audio': 0, 'cache_read': 2244}, 'output_token_details': {'reasoning': 196}}), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})

# %%
from random import random
from langchain_core.runnables.config import RunnableConfig

config = RunnableConfig(recursion_limit=10, configurable={"thread_id": str(random())})


input = State(messages=[HumanMessage(content="AI 관련 최신 뉴스를 검새해주세요")])

for chunk, metadata in graph.stream(input, config, stream_mode="messages"):
  print(metadata)
# Out:
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# ...
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 1, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
# {'thread_id': '0.8734900516446448', 'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('branch:to:tools',), 'langgraph_path': ('__pregel_pull', 'tools'), 'langgraph_checkpoint_ns': 'tools:dd9ba0c3-6d10-2055-554b-e5d6771d1107'}

# %% [markdown]
# ```json
# {
#   'thread_id': '0.8734900516446448',
#   'langgraph_step': 1,
#   'langgraph_node': 'chatbot',
#   'langgraph_triggers': ('branch:to:chatbot',),
#   'langgraph_path': ('__pregel_pull', 'chatbot'),
#   'langgraph_checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c',
#   'checkpoint_ns': 'chatbot:2e9da640-af3d-0325-d6fa-94578d74691c',
#   'ls_provider': 'openai',
#   'ls_model_name': 'x-ai/grok-4-fast:free',
#   'ls_model_type': 'chat',
#   'ls_temperature': 0.0
# }
# ```

# %%
from random import random
from langchain_core.messages import AIMessageChunk
from langchain_core.runnables.config import RunnableConfig

config = RunnableConfig(recursion_limit=10, configurable={"thread_id": str(random())})


input = State(messages=[HumanMessage(content="AI 관련 최신 뉴스를 검새해주세요")])

for chunk, metadata in graph.stream(input, config, stream_mode="messages"):
  if metadata["langgraph_node"] == "chatbot":
    if chunk.content:
      print(chunk.content, end="", flush=True)

# %%
from random import random
from langchain_core.messages import AIMessageChunk
from langchain_core.runnables.config import RunnableConfig

config = RunnableConfig(recursion_limit=10, configurable={"thread_id": str(random())})


input = State(messages=[HumanMessage(content="AI 관련 최신 뉴스를 검새해주세요")])

for chunk, metadata in graph.stream(input, config, stream_mode="messages"):
  if isinstance(chunk, AIMessageChunk):
    print(chunk.content, end="", flush=True)
  else:
    print(metadata["langgraph_node"])
# Out:
# tools
# ### AI 관련 최신 뉴스 (2024년 10월 초 기준)
#
# 안녕하세요! AI 관련 최신 뉴스를 검색해 보았습니다. 최근 1주일 내 주요 뉴스를 중심으로 요약해 드리겠습니다. (검색 기준: 2024-10-01 ~ 2024-10-08) 아래는 주요 기사들입니다. 더 자세한 내용은 링크를 클릭해 확인하세요.
#
# 1. **Cancer AI Alliance (CAIA) 출범: $40M 투자로 암 치료 AI 협력 강화**
#    - **요약**: 메타(Meta) 등 빅테크 기업들의 지원으로 4천만 달러 규모의 Cancer AI Alliance가 설립되었습니다. 의료 및 기술 전문가들이 연합해 연합 학습(federated learning)을 통해 프라이버시를 보호하면서 AI를 활용한 정밀 의료를 개발합니다. 이는 암 치료의 다음 세대를 위한 중요한 발걸음으로 평가됩니다.
#    - **출처**: TechCrunch
#    - **날짜**: 2024년 10월 2일
#    - **링크**: [TechCrunch 기사](https://techcrunch.com/2024/10/02/cancer-ai-alliance-joins-medical-and-tech-expertise-together-with-40m-to-collaborate-on-next-gen-care/)
#
# 2. **Google 검색 엔진에 AI 업그레이드: 비디오·사진에 대한 음성 질문 지원**
#    - **요약**: Google이 검색 엔진에 AI 기능을 추가해 사용자가 비디오나 사진에 대해 음성으로 질문을 하면 답변을 제공합니다. 이는 AI 개요(AI Overviews)를 통해 웹사이트 링크를 더 많이 포함시켜 뉴스 퍼블리셔들의 트래픽 감소를 완화하려는 노력의 일환입니다. 그러나 여전히 콘텐츠 크리에이터들의 우려가 남아 있습니다.
#    - **출처**: The Sun Chronicle
#    - **날짜**: 2024년 10월 3일
#    - **링크**: [The Sun Chronicle 기사](https://www.thesunchronicle.com/business/googles-search-engines-latest-ai-injection-will-answer-voiced-questions-about-video-and-photos/article_004b208e-d865-5bfc-ae8a-b8d3feb053c4.html)
#
# 3. **자율주행 개발을 위한 생성 AI 비디오 기술 업그레이드**
#    - **요약**: 자율주행 자동차 개발에서 생성 AI를 활용한 비디오 생성 기술이 업그레이드되었습니다. 이는 AI와 IoT가 농업 등 다른 분야에도 적용되는 추세를 반영하며, NASA와 IBM의 날씨 예측 AI 모델 등 관련 소식도 함께 언급됩니다. AI의 실생활 적용이 확대되고 있습니다.
#    - **출처**: AI Business
#    - **날짜**: 2024년 10월 3일
#    - **링크**: [AI Business 기사](https://aibusiness.com/generative-ai/generative-ai-video-for-self-driving-development-upgraded?__cf_chl_rt_tk=UH66E9_UsOGFR4iQWpIYvi802JakEKHaXAinDqpOH38-1727999366-0.0.1.1-5140)
#
# 이 뉴스들은 AI의 의료, 검색, 자율주행 분야에서의 최신 발전을 보여줍니다. 더 구체적인 주제(예: 특정 AI 기술이나 한국 관련 뉴스)나 추가 검색이 필요하시면 말씀해 주세요! 😊

# %%
from random import random
from langchain_core.runnables.config import RunnableConfig

config = RunnableConfig(recursion_limit=10, configurable={"thread_id": str(random())})


input = State(messages=[HumanMessage(content="AI 관련 최신 뉴스를 검새해주세요")])

for chunk, metadata in graph.stream(input, config, stream_mode="messages"):
  if metadata["langgraph_node"] == "tools":
    print(event)
# Out:
# (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--a4eef58e-d889-4b9d-acb2-9b518d626de2', usage_metadata={'input_tokens': 3095, 'output_tokens': 974, 'total_tokens': 4069, 'input_token_details': {'audio': 0, 'cache_read': 2244}, 'output_token_details': {'reasoning': 196}}), {'thread_id': '0.3348238247809542', 'langgraph_step': 3, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'checkpoint_ns': 'chatbot:8fc51aef-ad25-26d8-37fa-60db2afecc6f', 'ls_provider': 'openai', 'ls_model_name': 'x-ai/grok-4-fast:free', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
